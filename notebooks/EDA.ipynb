# %%
import pandas as pd
import glob 
import matplotlib.pyplot as plt
import numpy as np
  
  
raw_data_path = '../data/raw'
file_list = glob.glob(raw_data_path + "/*.csv")

# %%
file_list
# Out:
# ['../data/raw\\1к_2025-04-30_20-54.csv',
#  '../data/raw\\2к_2025-04-30_20-58.csv',
#  '../data/raw\\3к_2025-04-30_21-02.csv']

# %%
main_dataframe = pd.read_csv(file_list[0], delimiter=',')
for i in range(1, len(file_list)): 
    data = pd.read_csv(file_list[i], delimiter=',') 
    df = pd.DataFrame(data) 
    main_dataframe = pd.concat([main_dataframe, df], axis=0)

# %%
main_dataframe
# Out:
#              author        author_type  \
# 0       ID 12891703          homeowner
# 1         Whitewill  real_estate_agent
# 2      ID 130430577          homeowner
# 3     Доступный дом  real_estate_agent
# 4      Семен Гордый            realtor
# ...             ...                ...
# 1254          ANWIN  real_estate_agent
# 1255       ГОРОБМЕН  real_estate_agent
# 1256           ОГРК  real_estate_agent
# 1257   Isaev Estate  real_estate_agent
# 1258    ID 96241627          homeowner
#
#                                            url location deal_type  \
# 0     https://www.cian.ru/sale/flat/315747133/   Москва      sale
# 1     https://www.cian.ru/sale/flat/315253252/   Москва      sale
# 2     https://www.cian.ru/sale/flat/316847288/   Москва      sale
# 3     https://www.cian.ru/sale/flat/316724491/   Москва      sale
# 4     https://www.cian.ru/sale/flat/286050252/   Москва      sale
# ...                                        ...      ...       ...
# 1254  https://www.cian.ru/sale/flat/316767637/   Москва      sale
# 1255  https://www.cian.ru/sale/flat/315688477/   Москва      sale
# 1256  https://www.cian.ru/sale/flat/313044363/   Москва      sale
# 1257  https://www.cian.ru/sale/flat/309432400/   Москва      sale
# 1258  https://www.cian.ru/sale/flat/315320259/   Москва      sale
#
#      accommodation_type  floor  floors_count  rooms_count  total_meters  \
# 0                  flat     10            18            1         32.00
# 1                  flat     71            79            1         79.00
# 2                  flat      3            17            1         35.50
# 3                  flat      3            17            1         35.40
# 4                  flat      5             9            1         42.50
# ...                 ...    ...           ...          ...           ...
# 1254               flat      7            16            3         58.38
# 1255               flat     24            40            3         62.00
# 1256               flat     10            22            3         79.80
# 1257               flat      5            30            3         70.00
# 1258               flat      2            25            3         95.00
#
#       price_per_month  commissions     price           district  \
# 0                  -1            0  13590000       Останкинский
# 1                  -1            0  75000000        Пресненский
# 2                  -1            0  12000000         Некрасовка
# 3                  -1            0  13880000                NaN
# 4                  -1            0   7150000                NaN
# ...               ...          ...       ...                ...
# 1254               -1            0  35950000        Даниловский
# 1255               -1            0  36000000        Даниловский
# 1256               -1            0  36100000          Лефортово
# 1257               -1            0  36500000  Хорошево-Мневники
# 1258               -1            0  36490000                NaN
#
#                             street house_number       underground  \
# 0                  Березовая аллея         19к1  Ботанический сад
# 1     1-й Красногвардейский проезд         22с2       Москва-Сити
# 2                       Лавриненко         13к3        Некрасовка
# 3                    Эдварда Грига           15          Потапово
# 4                   Семена Гордого           12          Крёкшино
# ...                            ...          ...               ...
# 1254                 Мустая Карима           12         Технопарк
# 1255      бульвар Братьев Весниных            1               ЗИЛ
# 1256                  Крузенштерна            2    Площадь Ильича
# 1257      Шелепихинская набережная         40к3          Шелепиха
# 1258                  Саларьевская         14к2         Саларьево
#
#                      residential_complex
# 0     Апарт-комплекс Легендарный квартал
# 1                            NEVA TOWERS
# 2                             Некрасовка
# 3                                    NaN
# 4                        Ново-Никольское
# ...                                  ...
# 1254                                 WOW
# 1255                              ЗИЛАРТ
# 1256                              Символ
# 1257                         Sydney City
# 1258                      Саларьево парк
#
# [3903 rows x 18 columns]

# %%
new_dataframe = main_dataframe[['total_meters', 'price', "floor", "floors_count", "rooms_count"]]

# %%
new_dataframe
# Out:
#       total_meters     price  floor  floors_count  rooms_count
# 0            32.00  13590000     10            18            1
# 1            79.00  75000000     71            79            1
# 2            35.50  12000000      3            17            1
# 3            35.40  13880000      3            17            1
# 4            42.50   7150000      5             9            1
# ...            ...       ...    ...           ...          ...
# 1254         58.38  35950000      7            16            3
# 1255         62.00  36000000     24            40            3
# 1256         79.80  36100000     10            22            3
# 1257         70.00  36500000      5            30            3
# 1258         95.00  36490000      2            25            3
#
# [3903 rows x 5 columns]

# %%
new_dataframe['price'].hist()
# Out:
# <Axes: >

# %%
new_dataframe = new_dataframe.dropna()

# %%
print(new_dataframe.describe())  # Статистика без выбросов
print(new_dataframe.isnull().sum())  # Проверка на оставшиеся NaN
# Out:
#        total_meters         price        floor  floors_count  rooms_count
# count   3903.000000  3.903000e+03  3903.000000   3903.000000  3903.000000
# mean      64.606480  4.409697e+07     9.188317     17.843710     1.960799
# std       36.343512  6.761763e+07     9.067074     13.931412     0.846950
# min        8.300000  1.300000e+06     1.000000      1.000000    -1.000000
# 25%       39.000000  1.170000e+07     3.000000      9.000000     1.000000
# 50%       55.100000  2.150000e+07     7.000000     14.000000     2.000000
# 75%       77.050000  4.536000e+07    12.000000     22.000000     3.000000
# max      495.000000  7.000000e+08    81.000000    117.000000     3.000000
# total_meters    0
# price           0
# floor           0
# floors_count    0
# rooms_count     0
# dtype: int64

# %%
def remove_outliers(df, column):
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    return df[(df[column] >= lower_bound) & (df[column] <= upper_bound)]

for col in ['total_meters', 'price', 'floor', 'floors_count', 'rooms_count']:
    new_dataframe = remove_outliers(new_dataframe, col)

# %%
new_dataframe.count()
# Out:
# total_meters    3076
# price           3076
# floor           3076
# floors_count    3076
# rooms_count     3076
# dtype: int64

# %%
new_dataframe.to_csv('..//data//cleaned_data.csv', index=False)
